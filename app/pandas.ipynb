# %%
import pandas as pd

url = "https://data.openml.org/datasets/0004/46359/dataset_46359.pq"

df = pd.read_parquet('/home/tais/Documents/knn-bayes/data/fraud_detection.pq')

df
# Out:
#       qtd_atrasos_5_dias  qtd_atrasos_15_dias  qtd_atrasos_30_dias  \
# 0                    1.0                  0.0                  0.0
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3                    NaN                  NaN                  NaN
# 4                    NaN                  NaN                  NaN
# ...                  ...                  ...                  ...
# 4151                 NaN                  NaN                  NaN
# 4152                 NaN                  NaN                  NaN
# 4153                 NaN                  NaN                  NaN
# 4154                 NaN                  NaN                  NaN
# 4155                 2.0                  2.0                  0.0
#
#       qtd_emprestimos_quitados  regiao  tipo_pagamento_0  tipo_pagamento_1  \
# 0                          0.0       6                 0                 0
# 1                          2.0       1                 0                 0
# 2                          1.0       6                 0                 0
# 3                          0.0       5                 0                 3
# 4                          2.0       3                 0                 0
# ...                        ...     ...               ...               ...
# 4151                       0.0       5                 0                 0
# 4152                       1.0       2                 0                 0
# 4153                       1.0       2                 0                 0
# 4154                       0.0       6                 0                 0
# 4155                       0.0       4                 0                 0
#
#       tipo_pagamento_2  tipo_pagamento_3  tipo_pagamento_4  ...  \
# 0                    6                 0                 0  ...
# 1                    0                 5                 0  ...
# 2                    4                 0                 0  ...
# 3                    0                 0                 0  ...
# 4                    6                 0                 0  ...
# ...                ...               ...               ...  ...
# 4151                 1                 0                 0  ...
# 4152                 4                 0                 0  ...
# 4153                 4                 0                 0  ...
# 4154                 4                 0                 0  ...
# 4155                 6                 0                 0  ...
#
#       dia_semana_ultimo_emprestimo  ano_primeiro_emprestimo  \
# 0                                2                     2015
# 1                                3                     2015
# 2                                6                     2015
# 3                                5                     2015
# 4                                2                     2015
# ...                            ...                      ...
# 4151                             2                     2016
# 4152                             2                     2016
# 4153                             1                     2016
# 4154                             0                     2016
# 4155                             4                     2015
#
#       mes_primeiro_emprestimo  dia_primeiro_emprestimo  \
# 0                           9                       28
# 1                          12                       21
# 2                           6                       30
# 3                           8                        3
# 4                           8                       30
# ...                       ...                      ...
# 4151                        5                       17
# 4152                        3                       11
# 4153                        4                       30
# 4154                        5                       20
# 4155                       12                        8
#
#       dia_semana_primeiro_emprestimo  ano_primeiro_atraso  \
# 0                                  1               2016.0
# 1                                  1                  NaN
# 2                                  5                  NaN
# 3                                  1                  NaN
# 4                                  3                  NaN
# ...                              ...                  ...
# 4151                               5                  NaN
# 4152                               0                  NaN
# 4153                               2                  NaN
# 4154                               0                  NaN
# 4155                               5               2016.0
#
#       mes_primeiro_atraso  dia_primeiro_atraso  dia_semana_primeiro_atraso  \
# 0                     1.0                 30.0                           2
# 1                     NaN                  NaN                          -1
# 2                     NaN                  NaN                          -1
# 3                     NaN                  NaN                          -1
# 4                     NaN                  NaN                          -1
# ...                   ...                  ...                         ...
# 4151                  NaN                  NaN                          -1
# 4152                  NaN                  NaN                          -1
# 4153                  NaN                  NaN                          -1
# 4154                  NaN                  NaN                          -1
# 4155                  2.0                 13.0                           2
#
#       fraude
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 4151       0
# 4152       1
# 4153       0
# 4154       0
# 4155       1
#
# [4156 rows x 29 columns]

# %%
column_mapping = {
    # atraso (Days Past Due)
    'dpd_5_cnt': 'qtd_atrasos_5_dias',
    'dpd_15_cnt': 'qtd_atrasos_15_dias',
    'dpd_30_cnt': 'qtd_atrasos_30_dias',

    # empréstimos
    'close_loans_cnt': 'qtd_emprestimos_quitados',

    # localização
    'federal_district_nm': 'regiao',

    # tipos de pagamento
    'payment_type_0': 'tipo_pagamento_0',
    'payment_type_1': 'tipo_pagamento_1',
    'payment_type_2': 'tipo_pagamento_2',
    'payment_type_3': 'tipo_pagamento_3',
    'payment_type_4': 'tipo_pagamento_4',
    'payment_type_5': 'tipo_pagamento_5',

    # histórico financeiro
    'past_billings_cnt': 'qtd_faturas_passadas',

    # scores
    'score_1': 'score_credito_1',
    'score_2': 'score_credito_2',

    # dados demográficos
    'age': 'idade',
    'gender': 'genero',

    # target
    'bad_flag': 'fraude',

    # data do empréstimo reportado
    'rep_loan_date_year': 'ano_ultimo_emprestimo',
    'rep_loan_date_month': 'mes_ultimo_emprestimo',
    'rep_loan_date_day': 'dia_ultimo_emprestimo',
    'rep_loan_date_weekday': 'dia_semana_ultimo_emprestimo',

    # primeiro empréstimo
    'first_loan_year': 'ano_primeiro_emprestimo',
    'first_loan_month': 'mes_primeiro_emprestimo',
    'first_loan_day': 'dia_primeiro_emprestimo',
    'first_loan_weekday': 'dia_semana_primeiro_emprestimo',

    # primeiro atraso
    'first_overdue_date_year': 'ano_primeiro_atraso',
    'first_overdue_date_month': 'mes_primeiro_atraso',
    'first_overdue_date_day': 'dia_primeiro_atraso',
    'first_overdue_date_weekday': 'dia_semana_primeiro_atraso'
}

# %%
df = df.rename(columns=column_mapping)

# %%
df.to_parquet("/home/tais/Documents/knn-bayes/data/fraud_detection.pq")

# %%
# remove todas as linha que tiver um valor nulo, vazio, none,nan
df = df.dropna()
print(df.head())
print(df.shape)
# Out:
# Empty DataFrame
# Columns: [qtd_atrasos_5_dias, qtd_atrasos_15_dias, qtd_atrasos_30_dias, qtd_emprestimos_quitados, regiao, tipo_pagamento_0, tipo_pagamento_1, tipo_pagamento_2, tipo_pagamento_3, tipo_pagamento_4, tipo_pagamento_5, qtd_faturas_passadas, score_credito_1, score_credito_2, idade, genero, ano_ultimo_emprestimo, mes_ultimo_emprestimo, dia_ultimo_emprestimo, dia_semana_ultimo_emprestimo, ano_primeiro_emprestimo, mes_primeiro_emprestimo, dia_primeiro_emprestimo, dia_semana_primeiro_emprestimo, ano_primeiro_atraso, mes_primeiro_atraso, dia_primeiro_atraso, dia_semana_primeiro_atraso, fraude]
# Index: []
#
# [0 rows x 29 columns]
# (0, 29)
