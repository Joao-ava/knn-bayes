# %%
import pandas as pd

url = "https://data.openml.org/datasets/0004/46359/dataset_46359.pq"

df = pd.read_parquet(url)

df.columns
# Out:
# Index(['dpd_5_cnt', 'dpd_15_cnt', 'dpd_30_cnt', 'close_loans_cnt',
#        'federal_district_nm', 'payment_type_0', 'payment_type_1',
#        'payment_type_2', 'payment_type_3', 'payment_type_4', 'payment_type_5',
#        'past_billings_cnt', 'score_1', 'score_2', 'age', 'gender', 'bad_flag',
#        'rep_loan_date_year', 'rep_loan_date_month', 'rep_loan_date_day',
#        'rep_loan_date_weekday', 'first_loan_year', 'first_loan_month',
#        'first_loan_day', 'first_loan_weekday', 'first_overdue_date_year',
#        'first_overdue_date_month', 'first_overdue_date_day',
#        'first_overdue_date_weekday'],
#       dtype='str')

# %%
column_mapping = {
    # atraso (Days Past Due)
    'dpd_5_cnt': 'qtd_atrasos_5_dias',
    'dpd_15_cnt': 'qtd_atrasos_15_dias',
    'dpd_30_cnt': 'qtd_atrasos_30_dias',

    # empréstimos
    'close_loans_cnt': 'qtd_emprestimos_quitados',

    # localização
    'federal_district_nm': 'regiao',

    # tipos de pagamento
    'payment_type_0': 'tipo_pagamento_0',
    'payment_type_1': 'tipo_pagamento_1',
    'payment_type_2': 'tipo_pagamento_2',
    'payment_type_3': 'tipo_pagamento_3',
    'payment_type_4': 'tipo_pagamento_4',
    'payment_type_5': 'tipo_pagamento_5',

    # histórico financeiro
    'past_billings_cnt': 'qtd_faturas_passadas',

    # scores
    'score_1': 'score_credito_1',
    'score_2': 'score_credito_2',

    # dados demográficos
    'age': 'idade',
    'gender': 'genero',

    # target
    'bad_flag': 'inadimplente',

    # data do empréstimo reportado
    'rep_loan_date_year': 'ano_ultimo_emprestimo',
    'rep_loan_date_month': 'mes_ultimo_emprestimo',
    'rep_loan_date_day': 'dia_ultimo_emprestimo',
    'rep_loan_date_weekday': 'dia_semana_ultimo_emprestimo',

    # primeiro empréstimo
    'first_loan_year': 'ano_primeiro_emprestimo',
    'first_loan_month': 'mes_primeiro_emprestimo',
    'first_loan_day': 'dia_primeiro_emprestimo',
    'first_loan_weekday': 'dia_semana_primeiro_emprestimo',

    # primeiro atraso
    'first_overdue_date_year': 'ano_primeiro_atraso',
    'first_overdue_date_month': 'mes_primeiro_atraso',
    'first_overdue_date_day': 'dia_primeiro_atraso',
    'first_overdue_date_weekday': 'dia_semana_primeiro_atraso'
}

# %%
df = df.rename(columns=column_mapping)

# %%
# remove todas as linha que tiver um valor nulo, vazio, none,nan
df = df.dropna()
print(df.head())
print(df.shape)
# Out:
# Empty DataFrame
# Columns: [qtd_atrasos_5_dias, qtd_atrasos_15_dias, qtd_atrasos_30_dias, qtd_emprestimos_quitados, regiao, tipo_pagamento_0, tipo_pagamento_1, tipo_pagamento_2, tipo_pagamento_3, tipo_pagamento_4, tipo_pagamento_5, qtd_faturas_passadas, score_credito_1, score_credito_2, idade, genero, inadimplente, ano_ultimo_emprestimo, mes_ultimo_emprestimo, dia_ultimo_emprestimo, dia_semana_ultimo_emprestimo, ano_primeiro_emprestimo, mes_primeiro_emprestimo, dia_primeiro_emprestimo, dia_semana_primeiro_emprestimo, ano_primeiro_atraso, mes_primeiro_atraso, dia_primeiro_atraso, dia_semana_primeiro_atraso]
# Index: []
#
# [0 rows x 29 columns]
# (0, 29)
